# %% [markdown]
# # Segmentacion de clientes

# %% [markdown]
# Importación y lectura del archivo

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file = pd.read_csv('Mall_Customers.csv') # Archivo csv ubicado en la misma ruta del documento notebook

# %% [markdown]
# Ahora se puede mostrar la cabecera del contenido del documento

# %%
file.head()
# Out:
#    ID       Sexo  Edad  Ingreso anual (k$)  Puntuacion de gatos (1-100)
# 0   1  Masculino    19                  15                           39
# 1   2  Masculino    21                  15                           81
# 2   3   Femenino    20                  16                            6
# 3   4   Femenino    23                  16                           77
# 4   5   Femenino    31                  17                           40

# %%
file.describe()
# Out:
#                ID        Edad  Ingreso anual (k$)  Puntuacion de gatos (1-100)
# count  200.000000  200.000000          200.000000                   200.000000
# mean   100.500000   38.850000           60.560000                    50.200000
# std     57.879185   13.969007           26.264721                    25.823522
# min      1.000000   18.000000           15.000000                     1.000000
# 25%     50.750000   28.750000           41.500000                    34.750000
# 50%    100.500000   36.000000           61.500000                    50.000000
# 75%    150.250000   49.000000           78.000000                    73.000000
# max    200.000000   70.000000          137.000000                    99.000000

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           200 non-null    int64
#  1   Sexo                         200 non-null    object
#  2   Edad                         200 non-null    int64
#  3   Ingreso anual (k$)           200 non-null    int64
#  4   Puntuacion de gatos (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# seaborn.countplot Muestra el conteo de las muestras con un gráfico de barras

# %%
sns.countplot(file['Sexo'])
# Out:
# c:\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sexo', ylabel='count'>

# %% [markdown]
# seaborn.distplot Para la generación de histogramas

# %%
sns.distplot(file['Ingreso anual (k$)'])
# Out:
# c:\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ingreso anual (k$)', ylabel='Density'>

# %% [markdown]
# seaborn.catplot Muestra las relaciones entre las variables.

# %%
sns.catplot(x="Sexo", y="Edad", kind="box", data=file);

# %% [markdown]
# ## Metología K-medias

# %% [markdown]
# ### Ingresos anuales - Puntuación de gastos

# %% [markdown]
# Buscar el número más óptimo de clústeres aplicando el método del codo.

# %%
data=file.iloc[:,[3,4]].values # Se especifica que se tomarán en cuenta solo las columnas en las posiones 3 y 4 
                               # (Ingresos anuales y Puntuación de gastos)
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('Método del codo')
plt.xlabel('Número de clústers')
plt.ylabel('Suma total de errores cuadráticos')
plt.show()

# %% [markdown]
# Aplicación del algoritmo K-medias

# %%
kmeans=KMeans(n_clusters=5,init='k-means++',random_state=0)
y_kmeans=kmeans.fit_predict(data)

###Trazamiento de clústeres
fig,ax = plt.subplots(figsize=(14,6))
ax.scatter(data[y_kmeans==0,0],data[y_kmeans==0,1],s=100,c='red',label='Cluster 1')
ax.scatter(data[y_kmeans==1,0],data[y_kmeans==1,1],s=100,c='blue',label='Cluster 2')
ax.scatter(data[y_kmeans==2,0],data[y_kmeans==2,1],s=100,c='green',label='Cluster 3')
ax.scatter(data[y_kmeans==3,0],data[y_kmeans==3,1],s=100,c='cyan',label='Cluster 4')
ax.scatter(data[y_kmeans==4,0],data[y_kmeans==4,1],s=100,c='magenta',label='Cluster 5')

ax.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=400,c='yellow',label='Centroid')
plt.title('Segmentación de clientes')
plt.xlabel('Ingresos anuales (K$)')
plt.ylabel('Puntuación de gastos (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ### Edad - Puntuación de gastos

# %% [markdown]
# Método del codo para EDAD y PUNTACIÓN DE GATOS

# %%
data = file.iloc[:,[2,4]].values # Se indica que se utilizarán las columna 2 y 4 (Edad, Puntuación de gastos).
from sklearn.cluster import KMeans
wcss=[]  
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_) 

plt.plot(range(1,11),wcss)
plt.title('Método del codo')
plt.xlabel('Número de clústers')
plt.ylabel('Suma total de errores cuadráticos')
plt.show()

# %% [markdown]
# Aplicación del algoritmo K-medias

# %%
kmeans=KMeans(n_clusters=4,init='k-means++',random_state=0)
y_kmeans=kmeans.fit_predict(data)

#Plotting the clusters
fig,ax = plt.subplots(figsize=(14,6))
ax.scatter(data[y_kmeans==0,0],data[y_kmeans==0,1],s=100,c='red',label='Cluster 1')
ax.scatter(data[y_kmeans==1,0],data[y_kmeans==1,1],s=100,c='blue',label='Cluster 2')
ax.scatter(data[y_kmeans==2,0],data[y_kmeans==2,1],s=100,c='green',label='Cluster 3')
ax.scatter(data[y_kmeans==3,0],data[y_kmeans==3,1],s=100,c='cyan',label='Cluster 4')

ax.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=400,c='yellow',label='Centroid')
plt.title('Segmentación de clientes')
plt.xlabel('Edad')
plt.ylabel('Puntuación de gastos (1-100)')
plt.legend()
plt.show()
